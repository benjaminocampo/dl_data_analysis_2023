# %%
import matplotlib.pyplot as plt
import pandas

import seaborn
seaborn.set_context('talk')
pandas.set_option("display.max_columns", None)

melb_df = pandas.read_csv('../data/non_nan_values_melb.csv')
melb_df[:3]
# Out:
#    Unnamed: 0      Suburb          Address  Rooms Type      Price Method  \
# 0           0  Abbotsford     85 Turner St      2    h  1480000.0      S
# 1           1  Abbotsford  25 Bloomburg St      2    h  1035000.0      S
# 2           2  Abbotsford     5 Charles St      3    h  1465000.0     SP
#
#   SellerG       Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  Biggin  3/12/2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 1  Biggin  4/02/2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 2  Biggin  4/03/2017       2.5    3067.0       3.0       2.0  0.0     134.0
#
#    BuildingArea CouncilArea  Lattitude  Longtitude             Regionname  \
# 0    137.374429       Yarra   -37.7996    144.9984  Northern Metropolitan
# 1     79.000000       Yarra   -37.8079    144.9934  Northern Metropolitan
# 2    150.000000       Yarra   -37.8093    144.9944  Northern Metropolitan
#
#    Propertycount  suburb_count CouncilArea_mode
# ...

# %%
categorical_vars = ['Suburb', 'Type', 'Method', 'SellerG', 'CouncilArea', 'Regionname']
numerical_vars = ["Bedroom2", "BuildingArea", "Longtitude", "Car", "Postcode", "Bathroom", "Distance", "Lattitude", "Rooms", "suburb_count", "Price", "Propertycount", "Landsize"]

# %%
melb_df[categorical_vars]
# Out:
#              Suburb Type Method        SellerG  CouncilArea  \
# 0        Abbotsford    h      S         Biggin        Yarra
# 1        Abbotsford    h      S         Biggin        Yarra
# 2        Abbotsford    h     SP         Biggin        Yarra
# 3        Abbotsford    h     PI         Biggin        Yarra
# 4        Abbotsford    h     VB         Nelson        Yarra
# ...             ...  ...    ...            ...          ...
# 10691      Werribee    h      S  hockingstuart      Wyndham
# 10692  Williamstown    h     SP       Williams  Hobsons Bay
# 10693  Williamstown    h      S          Raine  Hobsons Bay
# 10694  Williamstown    h     PI        Sweeney  Hobsons Bay
# 10695    Yarraville    h     SP        Village  Maribyrnong
#
#                   Regionname
# 0      Northern Metropolitan
# 1      Northern Metropolitan
# 2      Northern Metropolitan
# 3      Northern Metropolitan
# 4      Northern Metropolitan
# ...                      ...
# 10691   Western Metropolitan
# ...

# %% [markdown]
# # Exercises
#
# ## Exercise 1 - Queries and use of Pandas.
#
# - Calculate the 5 highest-priced (column `Price`) suburbs on average in Melbourne.
#
# - Calculate the mean, median, max, min, and quartiles of grouping by `Type`
# and `SellerG`.
#
# - Retrieve the number of properties in Melbourne that have less or equal than one bathroom and
# which are located in suburbs with more than 200 properties, (don't use
# `Propertycount`)
#
# ## Exercise 2 - OHE and PCA.
#
# - Encode all the categorical columns `Suburb`, `Type`, `Method`, `SellerG`, `CouncilArea`, and `Regionname` of `melb_df` using one hot encoder.
#
# - Standarize numerical columns (Difference each random variable by the mean and divide by their standard deviation) `Bedroom2`, `BuildingArea`, `Longtitude`, `Car`, `Postcode`, `Bathroom`, `Distance`, `Lattitude`, `Rooms`, `suburb_count`, `Price`, `Propertycount`, and `Landsize`.
#
# - Apply PCA to the standarized numerical columns.
#
# - Concat the encodings of PCA and the one hot encoded columns in one dataframe.
